# %%
import json
import pandas as pd
import numpy as np

# %%
url = "https://data.sfgov.org/resource/wg3w-h783.json?$limit=500";

data = pd.read_json(url) 

data.head()
# Out:
#          incident_datetime            incident_date       incident_time  \
# 0  2019-05-01T01:00:00.000  2019-05-01T00:00:00.000 2020-04-09 01:00:00
# 1  2019-06-22T07:45:00.000  2019-06-22T00:00:00.000 2020-04-09 07:45:00
# 2  2019-06-03T16:16:00.000  2019-06-03T00:00:00.000 2020-04-09 16:16:00
# 3  2018-11-16T16:34:00.000  2018-11-16T00:00:00.000 2020-04-09 16:34:00
# 4  2019-05-27T02:25:00.000  2019-05-27T00:00:00.000 2020-04-09 02:25:00
#
#    incident_year incident_day_of_week          report_datetime       row_id  \
# 0           2019            Wednesday  2019-06-12T20:27:00.000  81097515200
# 1           2019             Saturday  2019-06-22T08:05:00.000  81465564020
# 2           2019               Monday  2019-06-03T16:16:00.000  80769875000
# 3           2018               Friday  2018-11-16T16:34:00.000  73857915041
# 4           2019               Monday  2019-05-27T02:55:00.000  80509204134
#
# ...

# %%
data.describe()
# Out:
#        incident_year        row_id    incident_id  incident_number  \
# count     500.000000  5.000000e+02     500.000000     5.000000e+02
# mean     2019.508000  8.597522e+10  859751.904000     1.962422e+08
# std         0.647127  5.468253e+09   54682.543776     6.526423e+06
# min      2018.000000  7.323663e+10  732366.000000     1.610102e+08
# 25%      2019.000000  8.176635e+10  817663.250000     1.905154e+08
# 50%      2020.000000  8.986001e+10  898600.000000     2.000832e+08
# 75%      2020.000000  8.987306e+10  898730.500000     2.000847e+08
# max      2020.000000  8.988811e+10  898881.000000     2.060245e+08
#
#          cad_number  incident_code           cnn  supervisor_district  \
# count  4.190000e+02     500.000000  4.670000e+02           467.000000
# mean   1.967290e+08   27244.058000  2.559560e+07             6.081370
# std    5.326730e+06   26896.750972  3.377745e+06             2.754983
# min    1.808863e+08    3054.000000  2.012100e+07             1.000000
# ...

# %%
filtered_df = data.filter(items = ["incident_id", "incident_date", "latitude", "longitude", "incident_category"])
filtered_latlon_df = filtered_df.dropna()

filtered_latlon_df
# Out:
#      incident_id            incident_date   latitude   longitude  \
# 0         810975  2019-05-01T00:00:00.000  37.762569 -122.499627
# 1         814655  2019-06-22T00:00:00.000  37.780535 -122.408161
# 2         807698  2019-06-03T00:00:00.000  37.721600 -122.390745
# 3         738579  2018-11-16T00:00:00.000  37.794860 -122.404876
# 4         805092  2019-05-27T00:00:00.000  37.797716 -122.430559
# ..           ...                      ...        ...         ...
# 495       898811  2020-02-03T00:00:00.000  37.780927 -122.413676
# 496       898666  2020-02-03T00:00:00.000  37.730318 -122.404706
# 497       898582  2020-02-03T00:00:00.000  37.732503 -122.409432
# 498       786464  2019-04-03T00:00:00.000  37.783101 -122.419182
# 499       898544  2020-02-02T00:00:00.000  37.736015 -122.384746
#
#                             incident_category
# 0    Offences Against The Family And Children
# 1                                Non-Criminal
# ...

# %%
#  create the 2019 dataframe (Dec 2018 - April 2019)

data.
# Out:
#            incident_datetime            incident_date       incident_time  \
# 0    2019-05-01T01:00:00.000  2019-05-01T00:00:00.000 2020-04-09 01:00:00
# 1    2019-06-22T07:45:00.000  2019-06-22T00:00:00.000 2020-04-09 07:45:00
# 2    2019-06-03T16:16:00.000  2019-06-03T00:00:00.000 2020-04-09 16:16:00
# 3    2018-11-16T16:34:00.000  2018-11-16T00:00:00.000 2020-04-09 16:34:00
# 4    2019-05-27T02:25:00.000  2019-05-27T00:00:00.000 2020-04-09 02:25:00
# ..                       ...                      ...                 ...
# 495  2020-02-03T15:25:00.000  2020-02-03T00:00:00.000 2020-04-09 15:25:00
# 496  2020-02-03T09:13:00.000  2020-02-03T00:00:00.000 2020-04-09 09:13:00
# 497  2020-02-03T00:45:00.000  2020-02-03T00:00:00.000 2020-04-09 00:45:00
# 498  2019-04-03T11:04:00.000  2019-04-03T00:00:00.000 2020-04-09 11:04:00
# 499  2020-02-02T19:36:00.000  2020-02-02T00:00:00.000 2020-04-09 19:36:00
#
#      incident_year incident_day_of_week          report_datetime       row_id  \
# ...
